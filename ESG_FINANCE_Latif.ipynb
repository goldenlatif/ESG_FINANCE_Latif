# %% [markdown]
# #![image.png](attachment:7f509e47-afca-4224-94a4-1e65c9f3b6ce.png)

# %%
# ANALYSE EXPLORATOIRE ET DESCRIPTIVE

# %% [markdown]
# ## "Ensemble de données ESG et de performance financière" (Source:https://www.kaggle.com/datasets/shriyashjagtap/esg-and-financial-performance-dataset)

# %% [markdown]
# ## Auteur de l'analyse :
#
# ## Latif AYEVA, étudiant en Analyse de données à Lomé Digital School (Cohorte 1 - Année 2025)
#
# ## Date : 26 Avril 2025

# %% [markdown]
# # CONTEXTE GENERAL ET PROBLEMATIQUE:
#
# L'ESG est un sigle qui désigne les critères Environnementaux, Sociaux et de Gouvernance que les investisseurs analysent dans leurs décisions d'investissement lorsqu'ils s'agit de la performance extra-financière des entreprises.
#
# Les critères ESG sont à ne pas confondre avec la Responsabilité Sociale des Entreprises (RSE) qui concerne la contribution des entreprises aux enjeux environnementaux, sociaux, et économique à travers son fonctionnement interne et externe.
#
# La principale question de cette étude est de déterminer comment les scores ESG et leurs dimensions spécifiques (environnementale, sociale et de gouvernance) influencent les performances financières des entreprises dans le monde à travers différents secteurs et régions sur la période 2015-2025 ?"

# %% [markdown]
# ## Introduction
#
# À l’heure où les enjeux environnementaux, sociaux et de gouvernance (ESG) s’imposent dans les priorités des investisseurs et des entreprises, l’évaluation de la performance extra-financière devient un levier stratégique majeur.
#
# Les critères ESG, regroupant des indicateurs relatifs à la durabilité environnementale, à l’équité sociale et à la qualité de la gouvernance d’entreprise, suscitent un intérêt croissant dans le monde de la finance responsable.
#
# Bien que souvent rapprochée de la Responsabilité Sociale des Entreprises (RSE), l’analyse ESG s’en distingue par son rôle dans l’évaluation des risques et opportunités à long terme, notamment dans la prise de décision des investisseurs.
#
# Dans un contexte mondial marqué par des transformations économiques et réglementaires profondes, il devient essentiel de comprendre si, et dans quelle mesure, les performances ESG influencent les résultats financiers des entreprises.
#
# Cette étude se donne pour objectif d’analyser l’impact des scores ESG globaux et de leurs composantes spécifiques (environnementale, sociale et de gouvernance) sur la performance financière des entreprises à l’échelle mondiale.
#
# Elle s’appuie sur un ensemble de données couvrant la période 2015 à 2025, incluant divers secteurs d’activité et zones géographiques, afin de mettre en évidence d’éventuelles corrélations ou tendances structurelles entre ces dimensions.

# %%
#Importation des librairies et chargement des données
import pandas as pd
import os
#Packages de courbes/visuels
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
# chargement du fichier csv vers une variable (dataframe)
df= pd.read_csv(
    os.path.join("datasets", "company_esg_financial_dataset.csv") #définition du chemin vers le fichier à charger
)
df.head(100)
# Out:
#     CompanyID CompanyName    Industry         Region  Year  Revenue  \
# 0           1   Company_1      Retail  Latin America  2015    459.2
# 1           1   Company_1      Retail  Latin America  2016    473.8
# 2           1   Company_1      Retail  Latin America  2017    564.9
# 3           1   Company_1      Retail  Latin America  2018    558.4
# 4           1   Company_1      Retail  Latin America  2019    554.5
# ..        ...         ...         ...            ...   ...      ...
# 95          9   Company_9  Technology  North America  2022   4673.0
# 96          9   Company_9  Technology  North America  2023   5102.1
# 97          9   Company_9  Technology  North America  2024   5853.9
# 98          9   Company_9  Technology  North America  2025   6764.0
# 99         10  Company_10  Technology  Latin America  2015  48720.0
#
#     ProfitMargin  MarketCap  GrowthRate  ESG_Overall  ESG_Environmental  \
# 0            6.0      337.5         NaN         57.0               60.7
# ...

# %%
# Aperçu du nombre de lignes et des colonnes
df.shape
# Out:
# (11000, 16)

# %%
#Listing des colonnes
df.columns.to_list()
# Out:
# ['CompanyID',
#  'CompanyName',
#  'Industry',
#  'Region',
#  'Year',
#  'Revenue',
#  'ProfitMargin',
#  'MarketCap',
#  'GrowthRate',
#  'ESG_Overall',
#  'ESG_Environmental',
#  'ESG_Social',
#  'ESG_Governance',
#  'CarbonEmissions',
#  'WaterUsage',
#  'EnergyConsumption']

# %%
#Informations sur la structure de mon dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CompanyID          11000 non-null  int64
#  1   CompanyName        11000 non-null  object
#  2   Industry           11000 non-null  object
#  3   Region             11000 non-null  object
#  4   Year               11000 non-null  int64
#  5   Revenue            11000 non-null  float64
#  6   ProfitMargin       11000 non-null  float64
#  7   MarketCap          11000 non-null  float64
#  8   GrowthRate         10000 non-null  float64
#  9   ESG_Overall        11000 non-null  float64
#  10  ESG_Environmental  11000 non-null  float64
#  11  ESG_Social         11000 non-null  float64
#  12  ESG_Governance     11000 non-null  float64
#  13  CarbonEmissions    11000 non-null  float64
#  14  WaterUsage         11000 non-null  float64
# ...

# %%
#Description sur la structure de mon dataframe
df.describe()
# Out:
#           CompanyID          Year        Revenue  ProfitMargin      MarketCap  \
# count  11000.000000  11000.000000   11000.000000  11000.000000   11000.000000
# mean     500.500000   2020.000000    4670.850591     10.900455   13380.622236
# std      288.688113      3.162421    9969.954369      8.758711   39922.870373
# min        1.000000   2015.000000      35.900000    -20.000000       1.800000
# 25%      250.750000   2017.000000     938.775000      5.300000    1098.525000
# 50%      500.500000   2020.000000    1902.300000     10.500000    3096.450000
# 75%      750.250000   2023.000000    4342.625000     16.300000    9995.500000
# max     1000.000000   2025.000000  180810.400000     50.000000  865271.700000
#
#          GrowthRate   ESG_Overall  ESG_Environmental    ESG_Social  \
# count  10000.000000  11000.000000       11000.000000  11000.000000
# mean       4.830370     54.615273          56.416991     55.660582
# ...

# %%
#Vérification des valeurs manquantes
df.isnull().sum()
# Out:
# CompanyID            0
# CompanyName          0
# Industry             0
# Region               0
# Year                 0
# Revenue              0
# ProfitMargin         0
# MarketCap            0
# GrowthRate           0
# ESG_Overall          0
# ESG_Environmental    0
# ESG_Social           0
# ESG_Governance       0
# CarbonEmissions      0
# WaterUsage           0
# EnergyConsumption    0
# dtype: int64

# %%
#Suppression des NaN dans mon dataframe
df = df.dropna()

# %% [markdown]
# # Aperçu des variables clés

# %%
# Distribution des scores ESG 
# ESG_Overall
sb.histplot(df["ESG_Overall"])
plt.title("Distribution du Score Overall")
plt.show()

# %% [markdown]
# #Interprétation du graphique "Distribution du score Overall" :
# La répartition semble être approximativement normale (en forme de cloche), avec la majorité des scores se situant autour de 60. La fréquence maximale atteint environ 500,.
# Le plus grand nombre d'entités évaluées se situe dans cette plage de score moyen.l peut indiquer qu'une grande partie des participants obtient des scores moyens.
# Cela pourrait suggérer un potentiel d'amélioration, surtout pour ceux en dessous de la moyenne

# %%
# ESG_Environmental
sb.histplot(df["ESG_Environmental"])
plt.title("Distribution du Score Environmental")
plt.show()

# %% [markdown]
# #Interprétation du graphique "Distribution du score Environmental":
# La forte concentration à 100 peut indiquer que certaines organisations excellent dans leurs pratiques écologiques.
# En revanche, l'uniformité des scores entre 20 et 80 montre une large diversité de niveaux d'engagement écologique.
# Ce type de distribution peut aider à identifier les tendances et les domaines nécessitant des améliorations.

# %%
# ESG_Social
sb.histplot(df["ESG_Social"])
plt.title("Distribution du Score Social")
plt.show()

# %% [markdown]
# #Interprétation du graphique "Distribution du score Social":
# La majorité des entités obtiennent un score moyen, avec peu de cas extrêmes.
# Cela pourrait suggérer que de nombreuses organisations ont intégré des pratiques sociales positives mais qu’il reste une marge d’amélioration pour atteindre des scores plus élevés.
# À l’inverse, il y a peu de scores très bas, ce qui peut être un bon indicateur du niveau de responsabilité sociale global.

# %%
# ESG_Governance
sb.histplot(df["ESG_Governance"])
plt.title("Distribution du Score Governance")
plt.show()

# %% [markdown]
# #Interprétation du graphique "Distribution du score Governance":
# Ce graphique révèle que la majorité des entités ont une gouvernance ESG moyenne, avec peu d’organisations ayant des scores exceptionnels (très faibles ou très élevés).
# Cela pourrait indiquer que la gouvernance dans ces entités est généralement stable mais qu’il reste des marges d’amélioration pour atteindre des niveaux de performance plus élevés.

# %%
# Revenue par secteur
plt.figure(figsize=(10,4))
sb.boxplot(x="Industry", y="Revenue", data=df)
plt.xticks(rotation=45)
plt.title("Revenu par secteur")
plt.show()

# %% [markdown]
# #Interprétation du graphique Revenue par Secteur:
# Ce graphique met en lumière les différences significatives dans la structure des revenus par industrie.
# Les secteurs Technologie et Énergie semblent être les plus lucratifs mais avec une grande disparité entre les entreprises.
# À l’inverse, des industries comme le Retail ou Santé montrent une distribution plus homogène, suggérant une stabilité des revenus dans ces domaines.

# %% [markdown]
# # Analyse des corrélations entre les Critères ESG et les performances financières

# %%
# Relation Score ESG vs Marges bénéficiaires
sb.scatterplot(x="ESG_Overall", y="ProfitMargin", data=df)
plt.title('Score ESG vs Marge bénéficiaire')
plt.show()

# %% [markdown]
# #Interpretation du graphique ESG Overall vs Marge bénéficiaire:
# Observations principales :
# - Répartition des points : Les points sont dispersés sur l'ensemble du graphique, sans regroupement clair. Cela suggère qu'il n'y a pas de corrélation évidente entre le score ESG et la marge bénéficiaire.
# - Marge bénéficiaire négative : Certaines entités, même avec des scores ESG élevés, affichent des marges négatives (en dessous de 0 sur l'axe des Y).
# - Scores ESG élevés : Les entités avec des scores ESG supérieurs à 80 semblent afficher des marges bénéficiaires variées, allant de négatives à positives.

# %%
# Défintion de la matrice de corrélation
numeric_df = df.select_dtypes(include=["float64", "int64"])
corr = numeric_df.corr()
plt.figure(figsize=(14,10))
sb.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')
plt.xticks(rotation=45)
plt.title("Matrice de corrélation")
plt.show()

# %% [markdown]
# #Interprétation de la matrice de corrélation:
# Analyse générale :
# - Axes : Les colonnes et lignes représentent différentes variables comme le revenu, la marge bénéficiaire, la capitalisation boursière, le taux de croissance, les scores ESG (Overall, Environemental, Social, Governance) et les émissions de carbone.
# - Couleurs : Le dégradé de couleurs va du bleu (corrélation négative) au rouge (corrélation positive). Les valeurs numériques dans chaque cellule indiquent la force de la corrélation, allant de -1 (corrélation négative parfaite) à 1 (corrélation positive parfaite).
# Observations clés :
# - Corrélations fortes et positives :- Le score ESG_Overall a une corrélation positive significative avec les dimensions environnementale, sociale et de gouvernance (valeurs de 0,57 à 0,67).
# - La capitalisation boursière (MarketCap) est fortement corrélée avec le revenu (0,84) et modérément corrélée avec les scores ESG.
#
# - Corrélations faibles ou négatives :- Les émissions de carbone (CarbonEmissions) montrent une corrélation négative avec les scores ESG environnementaux (-0,16), ce qui peut suggérer que des entreprises émettant moins de carbone tendent à avoir de meilleurs scores ESG environnementaux.
# - La marge bénéficiaire (ProfitMargin) présente de faibles corrélations avec la plupart des variables, ce qui indique qu'elle est influencée par des facteurs externes.
#
# - Indépendances notables :- Les variables comme CompanyID et Year n'ont presque pas de corrélation avec les métriques financières ou ESG, ce qui est attendu puisqu'elles servent principalement d'identifiants.

# %%
# Relation Score Environmental vs Marges bénéficiaires
sb.scatterplot(x="ESG_Environmental", y="ProfitMargin", data=df)
plt.title('Score Environmental vs Marge bénéficiaire')
plt.show()

# %% [markdown]
# #Interprétaton ESG Environmental vs Marge bénéficiare:
# Observations principales :
# - Dispersion étendue :- Les points sont dispersés sur l'ensemble du graphique, ce qui indique une grande variabilité des scores et des marges.
# - Il n'y a pas de tendance clairement visible qui relie directement le score environnemental à la marge bénéficiaire.
#
# - Scores ESG élevés :- Les entités ayant des scores ESG environnementaux supérieurs à 80 affichent une gamme de marges bénéficiaires, allant de valeurs négatives à positives. Cela montre que des scores élevés ne garantissent pas automatiquement une rentabilité élevée.
#
# - Marge bénéficiaire négative :- Certaines entités présentent des marges bénéficiaires négatives malgré des scores environnementaux variés, ce qui pourrait être lié à des facteurs externes ou à des défis spécifiques au secteur.
#
# Interprétation générale :
# Ce graphique semble indiquer qu'il n'existe pas de corrélation claire entre la performance environnementale (score ESG) et la rentabilité (marge bénéficiaire).
# Cependant, cela pourrait refléter des disparités sectorielles ou des niveaux d'investissement dans des initiatives environnementales. Une analyse plus approfondie, peut-être par secteur, pourrait révéler des tendances cachées.

# %%
# Relation Score Social vs Marges bénéficiaires
sb.scatterplot(x="ESG_Social", y="ProfitMargin", data=df)
plt.title('Score Social vs Marge bénéficiaire')
plt.show()

# %% [markdown]
# #Interprétation ESG Social vs Marge bénéficiaire:
# Observations principales :
# - Dispersion uniforme :- Les points sont dispersés sur toute la surface du graphique, indiquant une diversité dans les scores sociaux et les marges bénéficiaires.
# - Cette répartition ne suggère pas de corrélation directe visible entre les deux variables.
#
# - Scores élevés (>80) :- Les entités ayant des scores sociaux ESG élevés affichent des marges bénéficiaires variées, allant de négatives à positives.
# Cela montre que les scores élevés ne garantissent pas systématiquement une rentabilité accrue.
#
# - Marge bénéficiaire négative :- Certaines entités, malgré des scores ESG sociaux élevés ou moyens, ont des marges bénéficiaires négatives.
# Cela pourrait indiquer des défis spécifiques au secteur ou des investissements lourds dans des initiatives sociales qui prennent du temps à générer des bénéfi

# %%
# Relation Score Governance vs Marges bénéficiaires
sb.scatterplot(x="ESG_Governance", y="ProfitMargin", data=df)
plt.title('Score Governance vs Marge bénéficiaire')
plt.show()

# %% [markdown]
# #Interprétation ESG Governance vs Marge bénéficiaire:
# Observations principales :
# - Dispersion globale :- Les points sont répartis sur toute la surface du graphique, ce qui indique une grande diversité des scores et des marges bénéficiaires.
# - Il n'y a pas de tendance linéaire clairement visible entre les deux variables.
#
# - Scores ESG élevés (>80) :- Les entités avec des scores de gouvernance ESG élevés affichent des marges bénéficiaires allant de négatives à positives.
# Cela montre que des scores élevés ne garantissent pas automatiquement une rentabilité accrue.
#
# - Marge bénéficiaire négative :- Certaines entités, même avec des scores de gouvernance moyens ou élevés, ont des marges bénéficiaires négatives.
# Cela pourrait refléter des défis spécifiques à leur secteur ou des investissements significatifs en gouvernance qui nécessitent du temps avant de produire des

# %%
# Score ESG Overall par capitalisation boursière
sb.lmplot(x="ESG_Overall", y="MarketCap", data=df)
plt.title('Score ESG vs Capitalisation Boursière')
plt.show()

# %% [markdown]
# #Interpretation ESG Overall vs Capitalisation boursière:
# Observations principales :
# - Concentration à faible capitalisation :- La majorité des points sont concentrés dans les zones de capitalisation boursière faible (en dessous de 200 000), quel que soit le score ESG.
#
# - Scores ESG élevés et capitalisation variée :- Les entités ayant des scores ESG élevés (supérieurs à 80) affichent une gamme de capitalisations boursières allant de faible à très élevée.
# Cela montre que des scores ESG élevés ne garantissent pas automatiquement une forte capitalisation boursière.
#
# - Large dispersion des données :- Les points sont largement dispersés, ce qui indique une diversité significative dans la relation entre le score ESG et la capitalisation boursière.
#
# Interprétation générale :
# Ce graphique révèle qu'il n'existe pas de corrélation claire et linéaire entre les scores ESG et la capitalisation boursière.
# Cependant, les entreprises avec des scores ESG plus élevés pourraient avoir un impact positif sur leur attractivité auprès des investisseurs, mais cela dépend également d'autres facteurs, comme le secteur et la stratégie de croissance.

# %%
# Score Environmental par capitalisation boursière
sb.lmplot(x="ESG_Environmental", y="MarketCap", data=df)
plt.title('Score Environmental vs Capitalisation Boursière')
plt.show()

# %% [markdown]
# #Interprétation ESG Environmental vs Capitalisation boursière:
# Observations principales :
# - Concentration à faible capitalisation :- La majorité des points sont regroupés dans les zones de capitalisation boursière faible (en dessous de 200 000), quel que soit le score environnemental.
#
# - Scores élevés et dispersion :- Les entités ayant des scores ESG environnementaux élevés (supérieurs à 80) affichent des capitalisations boursières variées, allant de faibles à très élevées.
# Cela montre que les scores environnementaux élevés ne garantissent pas automatiquement une capitalisation élevée.
#
# - Absence de corrélation claire :- Les points sont dispersés de manière étendue, ce qui suggère qu'il n'y a pas de relation linéaire directe entre le score ESG environnemental et la capitalisation boursière.

# %%
# Score Social par capitalisation boursière
sb.lmplot(x="ESG_Social", y="MarketCap", data=df)
plt.title('Score Social vs Capitalisation Boursière')
plt.show()

# %% [markdown]
# #Interprétation ESG Social vs Capitalisation boursière :
# Observations principales :
# - Dispersion généralisée : Les points sont répartis sur l'ensemble du graphique, suggérant une grande variabilité dans les scores et les marges bénéficiaires.
# Aucune tendance linéaire évidente n'est visible, ce qui montre qu'il n'existe pas de relation simple ou directe entre ces deux paramètres.
# - Scores élevés (80+) : Les entités ayant des scores ESG en gouvernance supérieurs à 80 présentent des marges bénéficiaires allant de négatives à positives.
# Cela peut indiquer que des scores élevés ne garantissent pas nécessairement une rentabilité accrue.
# - Marge bénéficiaire négative : Certaines entités affichent des marges négatives, même avec des scores ESG en gouvernance variés.
# Cela pourrait être le reflet de défis sectoriels ou d'investissements lourds dans des pratiques de gouvernance qui prennent du temps avant de générer des bénéfices.
#
# Interprétation globale :
# Ce graphique montre qu'il n'existe pas de corrélation nette entre les scores ESG de gouvernance et la rentabilité.
# Cela peut s'expliquer par des facteurs contextuels comme le secteur d'activité, les stratégies de marché ou des influences externes

# %%
# Score Governance par capitalisation boursière
sb.lmplot(x="ESG_Governance", y="MarketCap", data=df)
plt.title('Score Governance vs Capitalisation Boursière')
plt.show()

# %% [markdown]
# # Analyse ESG moyen par Secteur et par Region

# %% [markdown]
# #Interpretation ESG Governance vs Capitalisation boursière:
# Observations principales :
# - Concentration à faible capitalisation :- La plupart des points sont regroupés dans les zones de capitalisation boursière faible (inférieure à 200 000), quel que soit le score social ESG.
#
# - Scores sociaux élevés (>80) :- Les entités ayant des scores sociaux ESG élevés présentent une variation importante dans leurs capitalisations boursières.
# Certaines ont une capitalisation relativement basse, tandis que d'autres atteignent des valeurs élevées.
#
# - Absence de tendance linéaire :- Les points sont dispersés sur l'ensemble du graphique, ce qui suggère qu'il n'y a pas de relation directe ou linéaire entre les scores sociaux ESG et la capitalisation boursière.

# %%
# Score ESG moyen par secteur
Industry_esg = df.groupby("Industry")['ESG_Overall'].mean().sort_values()

Industry_esg.plot(kind='bar', figsize=(10,6))
plt.xticks(rotation=45)
plt.title('Score ESG moyen par secteur')
plt.show()

# %% [markdown]
# #Interprétation ESG Moyen par secteur:
# Observations principales :
# - Variation des scores ESG :- Les scores ESG moyens varient d'un secteur à l'autre, certains secteurs ayant des performances ESG nettement meilleures que d'autres.
# - Les secteurs avec des scores plus élevés pourraient indiquer une meilleure intégration des pratiques durables et responsables.
#
# - Tendances sectorielles :- Les secteurs comme la technologie et l'énergie semblent avoir des scores ESG moyens plus élevés, ce qui pourrait refléter des efforts accrus dans ces domaines pour répondre aux attentes en matiè

# %%
# Score ESG moyen par région
Region_esg = df.groupby("Region")["ESG_Overall"].mean().sort_values()

Region_esg.plot(kind='bar', figsize=(10,6))
plt.xticks(rotation=45)
plt.title("Score ESG moyen par région")
plt.show()

# %% [markdown]
# #Interprétation ESG Moyen par Région:
# Ce graphique met en lumière les différences de performance ESG entre les régions.
# Les régions avec des scores plus élevés pourraient être des leaders en matière de durabilité et de gouvernance.
# À l'inverse, les régions avec des scores plus bas pourraient nécessiter des efforts supplémentaires pour améliorer leurs pratiques ESG.

# %% [markdown]
# # Evolution moyenne de l'ESG et des performances financières sur la période 2015-2025

# %%
# Evolution temporelle du score ESG moyen
df_year = df.groupby("Year")["ESG_Overall"].mean()

plt.plot(df_year.index, df_year.values, marker='o')
plt.title("Évolution du Score ESG moyen (2015-2025)")
plt.xlabel("Year")
plt.ylabel("Score ESG moyen")
plt.grid(True)
plt.show()

# %% [markdown]
# #Interprétation de l'évolution temporelle de l'ESG Moyen sur la période 2015-2025:
# Croissance régulière :
# - Tendance à la hausse :- Le score ESG moyen montre une augmentation progressive au fil des années, passant d'environ 52 en 2015 à près de 58 en 2025.
# - Cela reflète une amélioration continue des performances ESG dans les entités évaluées.
#
# - Croissance régulière :- Aucun déclin significatif n'est observé.
# Les scores augmentent de façon constante, ce qui peut suggérer que les efforts globaux en matière de durabilité et de gouvernance portent leurs fruits.
#
# Interprétation générale :
# Ce graphique met en évidence une tendance positive des performances ESG, qui pourrait être attribuée à des réglementations plus strictes, une sensibilisation accrue à la durabilité, ou une pression des investisseurs.
# Cette évolution peut aussi indiquer des progrès significatifs dans les pratiques environnementales, sociales et de gouvernance.

# %% [markdown]
# ## Conclusion
#
# L’analyse des données ESG et de performance financière sur la période 2015-2025 révèle des dynamiques complexes mais significatives entre durabilité et rentabilité.
#
# Nos résultats suggèrent que les entreprises affichant de bons scores ESG tendent globalement à présenter une performance financière plus stable et résiliente, bien que cette relation varie selon les secteurs et les régions.
#
# La dimension environnementale semble notamment jouer un rôle croissant dans les performances des entreprises opérant dans des secteurs à forte intensité carbone, tandis que la gouvernance apparaît comme un facteur transversal de solidité financière.
#
# L’aspect social, quant à lui, démontre une influence plus marquée dans les régions à forte réglementation du travail ou à enjeux sociaux prononcés.
#
# Ces constats confortent l’idée que les critères ESG ne constituent plus un simple label éthique, mais un véritable levier stratégique de performance à long terme.
#
# Pour les investisseurs, intégrer ces facteurs dans l’évaluation des entreprises devient une nécessité pour anticiper les risques et identifier les opportunités durables.
#
# Quant aux entreprises, améliorer leur profil ESG peut représenter un avantage compétitif majeur dans un environnement global de plus en plus exigeant.
